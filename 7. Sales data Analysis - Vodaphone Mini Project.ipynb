# %% [markdown]
# #Vodaphone Sales Data Analysis Mini Project (USN:1BG17CS013, Name: Amit Ranjan Shashi)

# %%
#Task 1 - Identifying and importing essential libraries

# %%
import numpy as np
import pandas as pd
import sys
import seaborn as sns
import os

# %%
#Task 2 - Data loading and overview

# %%
#task 2.a> Load the dataset from a file 
df1 = pd.read_excel(r"C:\Users\Amit Shashi\Superstore.xls")
df1
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
#task 2.b> Look at the first 5 records of the data
df1.head()                                                #if we want to work on only 5 record then we can use-> df1=df1.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#task 2.c> print columns containg in data
print(list(df1.columns))                 #looking at all column names in form of list
# Out:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
#task 2.d.1> print attrbute count of dataset
print(df1.count(axis=0))                 #looking at all column names with tolal no of entries in it.
# Out:
# Row ID           9994
# Order ID         9994
# Order Date       9994
# Ship Date        9994
# Ship Mode        9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal Code      9994
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %%
#task 2.d.2>calculate mean
print(df1.mean(axis=0))
# Out:
# Row ID          4997.500000
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
#task 2.d.3> calculate max
print(df1.max(axis=0))
# Out:
# Row ID                                         9994
# Order ID                             US-2017-169551
# Order Date                      2017-12-30 00:00:00
# Ship Date                       2018-01-05 00:00:00
# Ship Mode                            Standard Class
# Customer ID                                ZD-21925
# Customer Name                    Zuschuss Donatelli
# Segment                                 Home Office
# Country                               United States
# City                                           Yuma
# State                                       Wyoming
# Postal Code                                   99301
# Region                                         West
# Product ID                          TEC-PH-10004977
# Category                                 Technology
# Sub-Category                                 Tables
# Product Name     netTALK DUO VoIP Telephone Service
# Sales                                       22638.5
# ...

# %%
#task 2.d.4> calculate min
print(df1.min(axis=0))
# Out:
# Row ID                                                           1
# Order ID                                            CA-2014-100006
# Order Date                                     2014-01-03 00:00:00
# Ship Date                                      2014-01-07 00:00:00
# Ship Mode                                              First Class
# Customer ID                                               AA-10315
# Customer Name                                        Aaron Bergman
# Segment                                                   Consumer
# Country                                              United States
# City                                                      Aberdeen
# State                                                      Alabama
# Postal Code                                                   1040
# Region                                                     Central
# Product ID                                         FUR-BO-10000112
# ...

# %%
#task 2.d.5> calculate standard deviation
print(df1.std(axis=0))
df1.describe()             #we can also use df1.describe() for finding mean,count,min, max all at once
# Out:
# Row ID          2885.163629
# Postal Code    32063.693350
# Sales            623.245101
# Quantity           2.225110
# Discount           0.206452
# Profit           234.260108
# dtype: float64
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# ...

# %%
#task 2.e.1> creating dataframe for finding missing or null values
df1=pd.DataFrame(df1)
print(df1)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
#task 2.e.2> Find out are there any missing or null values in the data for all columns

# %%
df1.isnull().sum()   #checking for missing values
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df1.dropna()         #pandas would drop any row with missing value
df1.dropna(axis=1)   #drop column with NULL value
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
#Task 3 - Find out the per unit price from the data

# %%
#task 3.a> Convert date time field into pandas time object
df1["Order Date"]= pd.to_datetime(df1["Order Date"])
df1["Ship Date"]= pd.to_datetime(df1["Ship Date"])
df1.info()
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
#task 3.b.1> Find out the price per unit from the data and create a column for it in the same data (part A)
#extracting sales and quantity info for calculation
s = df1['Sales']
q = df1['Quantity']
print(s,q)
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64 0       2
# 1       3
# 2       2
# 3       5
# 4       2
#        ..
# 9989    3
# 9990    2
# 9991    2
# 9992    4
# 9993    2
# Name: Quantity, Length: 9994, dtype: int64

# %%
#task 3.b.2> Find out the price per unit from the data and create a column for it in the same data (Part B)
#calculating price per unit
price_per_unit=s/q
price_per_unit
# Out:
# 0       130.9800
# 1       243.9800
# 2         7.3100
# 3       191.5155
# 4        11.1840
#           ...
# 9989      8.4160
# 9990     45.9800
# 9991    129.2880
# 9992      7.4000
# 9993    121.5800
# Length: 9994, dtype: float64

# %%
#task 3.b.3> Find out the price per unit from the data and create a column for it in the same data (Part C)
#adding colunm price per unit
df1["price_per_unit"] = price_per_unit
print(df1['price_per_unit'])
# Out:
# 0       130.9800
# 1       243.9800
# 2         7.3100
# 3       191.5155
# 4        11.1840
#           ...
# 9989      8.4160
# 9990     45.9800
# 9991    129.2880
# 9992      7.4000
# 9993    121.5800
# Name: price_per_unit, Length: 9994, dtype: float64

# %%
#Task 4- Find out the monthly revenue and analyze the findings

# %%
#task 4.a.1> Create a column with Year and month field only give a suitable name to it
df1['Month_Year'] = df1['Ship Date']
#task 4.1.b> saving data in my1 variable so original data dont get modified while calculation
df1
my1=df1['Ship Date']
my1
#task 4.1.c> Create a column with Year and month field only give a suitable name to it
my2=df1['Ship Date']
my2 = pd.to_datetime(my2, format='%y-%m-%d').dt.strftime('%y-%m')
df1['Month_Year'] = my2
df1['Month_Year']
print(df1['Month_Year'])
# Out:
# 0       16-11
# 1       16-11
# 2       16-06
# 3       15-10
# 4       15-10
#         ...
# 9989    14-01
# 9990    17-03
# 9991    17-03
# 9992    17-03
# 9993    17-05
# Name: Month_Year, Length: 9994, dtype: object

# %%
#Task 4.b>Create a separate dataset from the data which will have two columns , one which is created in step a of this task and second the monthly sales / revenue
#step1

monthly_sales_revenue = df1['Sales']*df1['Quantity']
monthly_sales_revenue
#step2
df2=pd.DataFrame(df1,columns=['Month_Year'])
df2['monthly_sales_revenue']=monthly_sales_revenue
#step3
df1.to_csv('df2_miniproject.csv')
df2.set_index('Month_Year')
df2.sort_values('Month_Year')    #use to sort***  we can also use groupby() etc                 
df2.head().groupby('Month_Year').sum()                           #we can clearly see in below df2 dataframe that Month_Year is in different format than original data
# Out:
#             monthly_sales_revenue
# Month_Year
# 15-10                   4832.6235
# 16-06                     29.2400
# 16-11                   2719.7400

# %%
#task 4.c> Plot this dataset

#step1
#Import matplotlib functions
import matplotlib.pyplot as plt
# %matplotlib inline

#step2
#Bar graph

#Quantities for plotting
mon_year = df2['Month_Year']
sales_rev = df2['monthly_sales_revenue']

#Plotting these in the form of bar graph
plt.bar(mon_year ,sales_rev , color = "teal")


#Giving name to our plot
plt.title("Month Year")

#Naming the axes 
plt.xlabel("Month Year")
plt.ylabel("Monthly Sales Revenue")

#Showing what we have plotted
plt.show()
#extra
plt.bar(mon_year.head(5) ,sales_rev.head(5) , color = "red")
plt.show()

# %%
df2.groupby('Month_Year').sum().plot()

# %%
#alternate method for sales per month
#Getting Month-Year from Order Date
results = df1.groupby('Month_Year').sum()
months = [month for month, df1 in df1.groupby('Month_Year')]
plt.figure(figsize=(15,5))
plt.plot(months,results['Sales'], color = '#b80045')
plt.xticks(months, rotation='vertical', size = 8)
plt.ylabel('Sales in USD')
plt.xlabel('Month')
#plt.grid()
plt.show()

# %%
#task 4.d> Describe your analysis for the monthly revenue observations.
#analysis of above plot data:
#1st- Average revenue is between 20000 to 40000
#2nd- Revenue increased more than 120000 twice a year
#3rd- we are unable to see x axis lebel because a lot of data is taken for this plot
#4th-red bar graph is for analysing specific event using head attribute

# %%
#task 5> Find out the yearly revenue and analyze the findings

# %%
#task 5.a>Create a column with Year field only give a suitable name to it
my3 = pd.to_datetime(my1, format='%y-%m-%d').dt.strftime('20%y')

# %%
#task 5.b> Create a separate dataset from the data which will have two columns ,one which is created in step a of this task and second the yearly sales / revenue
df3=pd.DataFrame(df1,columns=['Year'])
df3['Year']=my3
my3
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2015
# 4       2015
#         ...
# 9989    2014
# 9990    2017
# 9991    2017
# 9992    2017
# 9993    2017
# Name: Ship Date, Length: 9994, dtype: object

# %%
#task 5.c>
#yearly revenue observations
df1["Order_Year"] = pd.to_datetime(df1["Order Date"])
df1["Year"] = df1["Order_Year"].dt.year
yearwiseSales = df1.groupby("Year").agg({"Sales":np.sum})
yearwiseSales.plot()

# %%
#task 5.d>
#extracting the year of order (Alternate Method)
df1['order year']=df1['Order Date'].dt.year
df1['order year'].head()
#Sales per year
df1.groupby('order year')['Sales'].agg(['sum']).plot.bar()
plt.title('Year wise Total Sales')
# Out:
# Text(0.5, 1.0, 'Year wise Total Sales')

# %%
#Task 6>Finding out the monthly growth rate and analyse the findings
#a.Create a column in the monthly revenue dataset for monthly growth
#rate
#b.Find out the maximum monthly growth rate
#c.Plot the findings
#d.Describe the findings

# %%
## Monthly Growth
Monthly_Data = pd.DataFrame(results['Sales'])
Monthly_Data['Last_Month'] = np.roll(Monthly_Data['Sales'],1)
Monthly_Data
Monthly_Data = Monthly_Data.drop(Monthly_Data.index[0])
#Calculating Monthly Growth for each month:
Monthly_Data['Growth'] = (Monthly_Data['Sales']/Monthly_Data['Last_Month'])-1
Monthly_Data.head()
##Plotting Monthly Growth
results = Monthly_Data.drop(columns = ["Sales", "Last_Month"])
results['Months'] = results.index
results.reset_index(drop=True, inplace=True)
results.head()
plt.figure(figsize=(15,5))
plt.bar(results['Months'],results['Growth']*100, color = '#b80045')
plt.xticks(results['Months'], rotation='vertical', size = 8)
plt.ylabel('% Growth')
plt.xlabel('Month')
plt.title("\n Monthly Growth\n", size=25)
#plt.grid()
plt.show()

# %%
#task 7 - Finding out the most and least sold product id
#a.Create a new dataset including the product ids and total quantities sold for that id
#b.Find out the most sold product from the created dataset

# %%
df4=pd.DataFrame(df1,columns=['product ids','total quantities sold'])
df4['product ids']=df1['Product ID']
df4['total quantities sold']=df1['Quantity']
df4
# Out:
#           product ids  total quantities sold
# 0     FUR-BO-10001798                      2
# 1     FUR-CH-10000454                      3
# 2     OFF-LA-10000240                      2
# 3     FUR-TA-10000577                      5
# 4     OFF-ST-10000760                      2
# ...               ...                    ...
# 9989  FUR-FU-10001889                      3
# 9990  FUR-FU-10000747                      2
# 9991  TEC-PH-10003645                      2
# 9992  OFF-PA-10004041                      4
# 9993  OFF-AP-10002684                      2
#
# [9994 rows x 2 columns]

# %%
sale_Products = df4.groupby(["product ids"])['total quantities sold'].aggregate(np.sum).reset_index().sort_values('total quantities sold',ascending = False).head(20)
sns.barplot(x = "product ids",     # Data is groupedby this variable
            y= "total quantities sold",          
            data=sale_Products)

# %%
sale_Products = df1.groupby(["Product Name"])['Quantity'].aggregate(np.sum).reset_index().sort_values('Quantity',ascending = False).head(20)
sns.barplot(x = "Product Name",     # Data is groupedby this variable
            y= "Quantity",          
            data=sale_Products)

# %%
prod_sales = pd.DataFrame(df1.groupby('Product Name').sum()['Sales'])
prod_sales.sort_values(by=['Sales'], inplace=True, ascending=False)

#Calculating Top 5:
top_prods = prod_sales.head(5)
top_prods
# Out:
#                                                         Sales
# Product Name
# Canon imageCLASS 2200 Advanced Copier               61599.824
# Fellowes PB500 Electric Punch Plastic Comb Bind...  27453.384
# Cisco TelePresence System EX90 Videoconferencin...  22638.480
# HON 5400 Series Task Chairs for Big and Tall        21870.576
# GBC DocuBind TL300 Electric Binding System          19823.479

# %%
best_selling_prods = pd.DataFrame(df1.groupby('Product Name').sum()['Quantity'])
best_selling_prods.sort_values(by=['Quantity'], inplace=True, ascending=False)

#Calculating top 5:
best_selling_prods = best_selling_prods.head(5)
best_selling_prods
# Out:
#                             Quantity
# Product Name
# Staples                          215
# Staple envelope                  170
# Easy-staple paper                150
# Staples in misc. colors           86
# KI Adjustable-Height Table        74

# %%
#task 8 - Finding out the customer who bought most and least from us in terms of quantity
#a.Create a dataset containing name and quantities bought
#b.Find out the customer name and quantity, who bought maximum in quantityS

# %%
#top customer 
plt.figure(figsize=(16,8))
profitable = df1.sort_values('Quantity', ascending=False)
top10 = profitable.head(10)
top10[['Customer Name', 'Quantity']]
sns.barplot(x = "Customer Name", y= "Quantity", data=top10)

# %%
#top customer 
plt.figure(figsize=(16,8))
profitable = df1.sort_values('Quantity', ascending=True)
top20 = profitable.head(10)
top20[['Customer Name', 'Quantity']]
sns.barplot(x = "Customer Name", y= "Quantity", data=top20)

# %%
#task 9 - Finding out the customer who bought most and least from us in terms of value
#a.Create a dataset containing name and sales generated by him
#b.Find out the customer name and sales, who bought maximum in value

# %%
#Top 20 Customers who benefitted the store in terms os sales value
sortedTop20 = df1.sort_values(['Sales'], ascending=False).head(20)
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
p = sns.barplot(x='Customer Name', y='Sales',palette='Set1', data=sortedTop20, ax=ax)
ax.set_title("Top 20 Customers")
ax.set_xticklabels(p.get_xticklabels(), rotation=75)
plt.tight_layout()
plt.show()

# %%
#Least 20 Customers who benefitted the store in terms os sales value
sortedTop20 = df1.sort_values(['Sales'], ascending=False).tail(20)
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
p = sns.barplot(x='Customer Name', y='Sales',palette='Set1', data=sortedTop20, ax=ax)
ax.set_title("Least 20 Customers")
ax.set_xticklabels(p.get_xticklabels(), rotation=75)
plt.tight_layout()
plt.show()

# %%
#task 10
#Finding out the majority and minority customer cities on basis of
#a. Number of customers
#b. Sales value
#c. Number of quantity sold

# %%
result = df1.groupby(["Customer Name"])['Profit'].aggregate(np.sum).reset_index().sort_values('Profit',ascending = False).head(20)
result.head
type(result)
result.shape
result
sns.barplot(x = "Customer Name",y= "Profit",data=result)

# %%
df1['Sales'].value_counts()
# Out:
# 12.960    56
# 15.552    39
# 19.440    39
# 10.368    36
# 32.400    28
#           ..
# 18.528     1
# 5.700      1
# 62.192     1
# 60.600     1
# 52.000     1
# Name: Sales, Length: 6144, dtype: int64

# %%
df1['Customer Name'].value_counts()
# Out:
# William Brown        37
# Paul Prost           34
# Matt Abelman         34
# John Lee             34
# Jonathan Doherty     32
#                      ..
# Anthony O'Donnell     1
# Ricardo Emerson       1
# Lela Donovan          1
# Carl Jackson          1
# Jocasta Rupert        1
# Name: Customer Name, Length: 793, dtype: int64

# %%
#distribution of our customer city segment
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
p = sns.barplot(x="Quantity",y="City", data=df1, ax=ax)
ax.set_title("Customer Distribution by City")
ax.set_xticklabels(p.get_xticklabels(), rotation=90)
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))
plt.tight_layout()
plt.show()

# %%
Top_cities = df1.groupby(["City"]).sum().sort_values("Sales", ascending=False).head(20) # Sort the States as per the sales
Top_cities = Top_cities[["Sales"]].round(2) # Round off the Sales Value up to 2 decimal places
Top_cities.reset_index(inplace=True) # Since we have used groupby, we will have to reset the index to add the cities into the dataframe
plt.figure(figsize = (15,5)) # width and height of figure is defined in inches
plt.title("Cities which generated Highest Revenue (2015-2019)", fontsize=18)
plt.bar(Top_cities["City"], Top_cities["Sales"],color= '#95DEE3',edgecolor='blue', linewidth = 1)
plt.xlabel("Cities",fontsize=15)  # x axis shows the States
plt.ylabel("Revenue",fontsize=15)  # y axis shows the Revenue
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)
for k,v in Top_cities["Sales"].items(): #To show the exact revenue generated on the figure
    if v>250000:
        plt.text(k,v-75000,'$'+ str(v), fontsize=12,rotation=90,color='k', horizontalalignment='center');
    else:
        plt.text(k,v+15000,'$'+ str(v), fontsize=12,rotation=90,color='k', horizontalalignment='center');

# %%
#task 11 - Find out the most and least sold product category from the store
#a.Value based
#b.Quantity based

# %%
plt.figure(figsize=(12,10))
df1['Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
df1.groupby('Category')['Sales'].agg(['sum']).plot.bar()
plt.title('Total Sales per Category')
plt.show()

# %%
#Count/quantity of Category
import seaborn as sns
plt.figure(figsize=(15,8))
sns.barplot(x='Category',y='Sales', data=df1)
plt.show()

# %%
#Sales of Category
plt.figure(figsize=(15,8))
sns.barplot(x="Category",y='Sales', hue="Category", data=df1)
plt.show()

# %%
#task 12 - Find out the most and least sold product sub category from the store
#a.Value based
#b.Quantity based

# %%
plt.figure(figsize=(12,10))
df1['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
df1.groupby('Sub-Category')['Sales'].agg(['sum']).plot.bar()
plt.title('Total Sales per Sub-Category')
plt.show()

# %%
#sales of Sub-Category
import seaborn as sns
plt.figure(figsize=(15,8))
sns.barplot(x='Sub-Category',y='Sales', data=df1)
plt.show()

# %%
#Sales of Sub-Category
plt.figure(figsize=(15,8))
sns.barplot(x="Sub-Category",y='Sales', hue="Sub-Category", data=df1)
plt.show()
